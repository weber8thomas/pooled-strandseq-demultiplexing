# %%
import pandas as pd
import sys, os

df = pd.read_excel(
    "/scratch/tweber/DATA/1000G_SNV_with_GT/OTF/ANALYSIS/HGSVCxPool1.xlsx"
)
# df["Cell"] = df["QUERY_SAMPLE_CELL"].str.replace(
#     "iPSCsxcontrolx01PE20", "", regex=False
# )
# print(df.loc[df["Used/Not used in MC"] == 1])
# print(df.columns)
# print(
#     df.loc[df["Used/Not used in MC"] == 1][
#         ["QUERY_SAMPLE_CELL", "QUAL >= 10", "('SAMPLE', 1)"]
#     ]
# )

david_df = pd.DataFrame(
    [
        {
            "QUERY_SAMPLE_CELL": os.path.basename(f),
            "Cell": os.path.basename(f).split("_")[0].replace("HGSVCxpool3x01PE20", ""),
        }
        for f in os.listdir(
            "/g/korbel2/weber/MosaiCatcher_files/POOLING/POOLING_POOL3/HGSVCxpool3/all"
        )
        if f.endswith(".bam")
    ]
)
david_df
# Out:
#                                     QUERY_SAMPLE_CELL Cell
# 0   HGSVCxpool3x01PE20493_sorted_HG03456.sort.mdup...  493
# 1   HGSVCxpool3x01PE20401_sorted_NA18940.sort.mdup...  401
# 2   HGSVCxpool3x01PE20403_sorted_NA20536.sort.mdup...  403
# 3   HGSVCxpool3x01PE20407_sorted_HG01887.sort.mdup...  407
# 4   HGSVCxpool3x01PE20408_sorted_HG01887.sort.mdup...  408
# 5   HGSVCxpool3x01PE20409_sorted_NA20846.sort.mdup...  409
# 6   HGSVCxpool3x01PE20410_sorted_NA10857.sort.mdup...  410
# 7   HGSVCxpool3x01PE20411_sorted_HG01887.sort.mdup...  411
# 8   HGSVCxpool3x01PE20414_sorted_HG03522.sort.mdup...  414
# 9   HGSVCxpool3x01PE20415_sorted_HG03522.sort.mdup...  415
# 10  HGSVCxpool3x01PE20416_sorted_HG01255.sort.mdup...  416
# 11  HGSVCxpool3x01PE20418_sorted_HG00673.sort.mdup...  418
# 12  HGSVCxpool3x01PE20419_sorted_HG01887.sort.mdup...  419
# 13  HGSVCxpool3x01PE20420_sorted_HG00233.sort.mdup...  420
# 14  HGSVCxpool3x01PE20421_sorted_NA19139.sort.mdup...  421
# ...

# %%
df
# Out:
#         QUERY_SAMPLE_CELL  QUAL >= 0  QUAL >= 10 ('SAMPLE', 1)_x  \
# 0   HGSVCxpool1x01PE20401        1.0         NaN         HG02945
# 1   HGSVCxpool1x01PE20402       23.0         1.0         HG02615
# 2   HGSVCxpool1x01PE20403        4.0         NaN         HG00438
# 3   HGSVCxpool1x01PE20404        NaN         NaN             NaN
# 4   HGSVCxpool1x01PE20405        4.0         1.0         HG00438
# ..                    ...        ...         ...             ...
# 91  HGSVCxpool1x01PE20492        4.0         NaN         HG00097
# 92  HGSVCxpool1x01PE20493       13.0         1.0         HG02972
# 93  HGSVCxpool1x01PE20494        1.0         1.0         NA20862
# 94  HGSVCxpool1x01PE20495        1.0         NaN         HG00097
# 95  HGSVCxpool1x01PE20496       24.0         3.0         NA19705
#
#    ('SAMPLE', 2)_x ('SAMPLE', 3)_x  ('Counts', 1)_x  ('Counts', 2)_x  \
# 0              NaN             NaN              1.0              NaN
# ...

# %%
hgsvc_batch = df["QUERY_SAMPLE_CELL"].values.tolist()[0].split("xpool")[1][0]
print(hgsvc_batch)
# hgsvc_batch = "3"
ground_truth_path = "/g/korbel2/weber/MosaiCatcher_files/POOLING/POOLING_POOL{index}/HGSVCxpool{index}/all"

david_df = pd.DataFrame(
    [
        {
            "QUERY_SAMPLE_CELL": os.path.basename(f).split("_")[0],
            "DAVID_Sample": os.path.basename(f).split("_sorted_")[1].replace(".sort.mdup.bam", ""),
        }
        for f in os.listdir(ground_truth_path.format(index=hgsvc_batch))
        if f.endswith(".bam")
    ]
)
david_df
# Out:
# 1
#         QUERY_SAMPLE_CELL DAVID_Sample
# 0   HGSVCxpool1x01PE20402      HG04115
# 1   HGSVCxpool1x01PE20406      HG00766
# 2   HGSVCxpool1x01PE20409      HG00735
# 3   HGSVCxpool1x01PE20411      HG04115
# 4   HGSVCxpool1x01PE20423      NA20128
# 5   HGSVCxpool1x01PE20426      HG01273
# 6   HGSVCxpool1x01PE20428      HG01273
# 7   HGSVCxpool1x01PE20429      NA18965
# 8   HGSVCxpool1x01PE20430      HG01978
# 9   HGSVCxpool1x01PE20432      HG04115
# 10  HGSVCxpool1x01PE20433      NA18537
# 11  HGSVCxpool1x01PE20438      HG01273
# 12  HGSVCxpool1x01PE20440      NA18537
# 13  HGSVCxpool1x01PE20441      HG00735
# 14  HGSVCxpool1x01PE20452      NA18965
# 15  HGSVCxpool1x01PE20453      HG01106
# 16  HGSVCxpool1x01PE20457      HG00766
# 17  HGSVCxpool1x01PE20458      HG01978
# 18  HGSVCxpool1x01PE20459      NA18965
# 19  HGSVCxpool1x01PE20464      HG04115
# 20  HGSVCxpool1x01PE20466      NA19730
# 21  HGSVCxpool1x01PE20470      HG01273
# 22  HGSVCxpool1x01PE20473      HG04157
# ...
